# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/daily_campaign_performance.csv')

# %%
df
# Out:
#       visit_date  week  utm_source utm_medium               utm_campaign  \
# 0     2023-06-01    22      Yandex        cpc                   03997128
# 1     2023-06-01    22      Yandex        cpm                   01097402
# 2     2023-06-01    22     admitad        cpa                    admitad
# 3     2023-06-01    22    bing.com    organic                        NaN
# 4     2023-06-01    22  go.mail.ru    organic                        NaN
# ...          ...   ...         ...        ...                        ...
# 1616  2023-06-30    26      yandex        cpc     prof-professions-brand
# 1617  2023-06-30    26      yandex        cpc  prof-professions-retarget
# 1618  2023-06-30    26      yandex        cpc                prof-python
# 1619  2023-06-30    26  yandex.com    organic                        NaN
# 1620  2023-06-30    26         zen     social              prof-frontend
#
#       visitors_count  total_cost  leads_count  purchases_count  revenue  \
# ...

# %%
df.head(50)
# Out:
#     visit_date  week   utm_source utm_medium  \
# 0   2023-06-01    22       Yandex        cpc
# 1   2023-06-01    22       Yandex        cpm
# 2   2023-06-01    22      admitad        cpa
# 3   2023-06-01    22     bing.com    organic
# 4   2023-06-01    22   go.mail.ru    organic
# 5   2023-06-01    22       google        cpc
# 6   2023-06-01    22       google    organic
# 7   2023-06-01    22      organic    organic
# 8   2023-06-01    22     telegram        cpp
# 9   2023-06-01    22     telegram        cpp
# 10  2023-06-01    22     telegram        cpp
# 11  2023-06-01    22     telegram        cpp
# 12  2023-06-01    22     telegram        cpp
# 13  2023-06-01    22     telegram        cpp
# 14  2023-06-01    22     telegram        cpp
# 15  2023-06-01    22     telegram        cpp
# 16  2023-06-01    22     telegram     social
# 17  2023-06-01    22     telegram     social
# 18  2023-06-01    22      tproger        cpc
# 19  2023-06-01    22      twitter     social
# ...

# %%
df.sort_values(by=['revenue'])
# Out:
#       visit_date  week  utm_source utm_medium               utm_campaign  \
# 428   2023-06-10    23      google    organic                        NaN
# 24    2023-06-01    22          vk        cpc                base-python
# 897   2023-06-19    25      google    organic                        NaN
# 603   2023-06-14    24      google    organic                        NaN
# 605   2023-06-14    24     organic    organic                        NaN
# ...          ...   ...         ...        ...                        ...
# 1616  2023-06-30    26      yandex        cpc     prof-professions-brand
# 1617  2023-06-30    26      yandex        cpc  prof-professions-retarget
# 1618  2023-06-30    26      yandex        cpc                prof-python
# 1619  2023-06-30    26  yandex.com    organic                        NaN
# 1620  2023-06-30    26         zen     social              prof-frontend
#
#       visitors_count  total_cost  leads_count  purchases_count  revenue  \
# ...
